# %%
# !pip install matplotlib
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot([1,2,3,4],[1,2,3,4])
plt.show()

# %%
x = range(5)
print([xi for xi in x])
# Out:
# [0, 1, 2, 3, 4]

# %%
plt.plot(x,[xi**2 for xi in x])
plt.show()

# %%
import numpy
x = numpy.arange(0,5,0.01)
plt.plot(x,[xi**2 for xi in x])
plt.show()

# %%
x = range(5)
plt.plot(x,[xi for xi in x])
plt.plot(x,[xi*xi for xi in x])
plt.plot(x,[xi*xi*xi for xi in x])
plt.show()

# %%
x = range(5)
plt.figure()
plt.plot(x,[xi for xi in x])
plt.plot(x,[xi*2 for xi in x])
plt.plot(x,[xi*4 for xi in x])
plt.grid(True)
plt.xlim(-1,5)
plt.ylim(-1,10)
plt.show()

# %%
x = range(5)
plt.figure()
plt.plot(x,[xi for xi in x])
plt.plot(x,[xi*2 for xi in x])
plt.plot(x,[xi*4 for xi in x])
plt.grid(True)
plt.xlim(-1,5)
plt.ylim(-1,10)
plt.xlabel("Sales")
plt.ylabel("Count")
plt.show()

# %%
x = range(5)
plt.figure()
plt.plot(x,[xi for xi in x])
plt.plot(x,[xi*2 for xi in x])
plt.plot(x,[xi*4 for xi in x])
plt.grid(True)
plt.xlim(-1,5)
plt.ylim(-1,10)
plt.xlabel("Sales")
plt.ylabel("Count")
plt.title("Polynomial graph")
plt.show()

# %%
x = numpy.arange(5)
plt.figure()
plt.plot(x,x, label = 'Linear')
plt.plot(x,x*x, label = 'Square')
plt.plot(x,x*x*x, label = 'Cube')
plt.grid(True)
plt.xlim(-1,5)
plt.ylim(-1,10)
plt.xlabel("Sales")
plt.ylabel("Count")
plt.title("Polynomial graph")
plt.legend(loc = "upper left")
plt.show()

# %%
x = numpy.arange(5)
plt.figure()
plt.plot(x,x, label = 'Linear', ls = '--',c = 'y',marker = '+')
plt.plot(x,x*x, label = 'Square', ls = '-.',c = 'k', marker = 'D')
plt.plot(x,x*x*x, label = 'Cube', ls = ':',c = 'm', marker = '*')
plt.grid(True)
plt.xlim(-1,5)
plt.ylim(-1,10)
plt.xlabel("Sales")
plt.ylabel("Count")
plt.title("Polynomial graph")
plt.legend(loc = "upper left")
plt.savefig("D:\\DATA SCIENCE\\line.png")
plt.show()

# %%
x = numpy.random.randn(100)
plt.hist(x, bins = 5)
plt.show()

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.barplot(x = 'species', y = 'sepal_width', data = iris)

# %%
sns.barplot(x = 'species', y = 'sepal_width', data = iris,palette = 'spring')

# %%
sns.distplot(iris["petal_length"],label = 'petal_length',kde = False)

# %%
sns.scatterplot(x = 'petal_length', y = 'sepal_width', data = iris)

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights1 = flights.pivot('month','year','passengers')
flights1
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flights1,cmap = 'YlGnBu',linewidth = 2,xticklabels = True,yticklabels = True)

# %%
tips = sns.load_dataset('tips')
ax = sns.barplot("size", y="total_bill", data=tips,
                 palette="spring")
